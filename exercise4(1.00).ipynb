# %% [markdown]
# <a href="https://colab.research.google.com/github/chl-eo/CCADMACL_EXAM_COM222ML/blob/main/exercise4(1.00).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %%
# !wget https://bitbucket.org/ishaanjav/code-and-deploy-custom-tensorflow-lite-model/raw/a4febbfee178324b2083e322cdead7465d6fdf95/fruits.zip
# Out:
# --2025-04-22 07:27:18--  https://bitbucket.org/ishaanjav/code-and-deploy-custom-tensorflow-lite-model/raw/a4febbfee178324b2083e322cdead7465d6fdf95/fruits.zip
# Resolving bitbucket.org (bitbucket.org)... 13.200.41.135, 13.200.41.136, 13.200.41.134, ...
# Connecting to bitbucket.org (bitbucket.org)|13.200.41.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105946856 (101M) [application/zip]
# Saving to: ‘fruits.zip.1’
#
# fruits.zip.1        100%[===================>] 101.04M  17.1MB/s    in 6.2s
#
# 2025-04-22 07:27:26 (16.2 MB/s) - ‘fruits.zip.1’ saved [105946856/105946856]

# %%
# !unzip fruits.zip
# Out:
# Archive:  fruits.zip
# replace __MACOSX/._fruits? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 20

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 605 files belonging to 4 classes.
# Found 110 files belonging to 4 classes.
# Found 191 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
# !pip install Pillow
from PIL import Image

def convert_to_jpg(image_path):
    """Converts an image to JPEG format."""
    try:
        img = Image.open(image_path)
        if img.format != "JPEG":
            # Convert to RGB if necessary
            if img.mode != "RGB":
                img = img.convert("RGB")

            # Save as JPEG with original filename but .jpg extension
            new_path = image_path.rsplit('.', 1)[0] + '.jpg'
            img.save(new_path, "JPEG")
            print(f"Converted {image_path} to {new_path}")
            # Delete the original file if the conversion was successful
            import os
            os.remove(image_path)
        else:
            print(f"{image_path} is already a JPEG. Skipping.")
    except Exception as e:
        print(f"Error converting {image_path}: {e}")


import os
# Example usage: Convert all images in the "fruits/train" directory to JPEG
for dirpath, dirnames, filenames in os.walk("fruits/train"):
    for filename in filenames:
        image_path = os.path.join(dirpath, filename)
        convert_to_jpg(image_path)

# Repeat for validation and test directories
for dirpath, dirnames, filenames in os.walk("fruits/validation"):
    for filename in filenames:
        image_path = os.path.join(dirpath, filename)
        convert_to_jpg(image_path)

for dirpath, dirnames, filenames in os.walk("fruits/test"):
    for filename in filenames:
        image_path = os.path.join(dirpath, filename)
        convert_to_jpg(image_path)
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Error converting fruits/train/.DS_Store: cannot identify image file 'fruits/train/.DS_Store'
# fruits/train/orange/Screen Shot 2018-06-13 at 12.18.34 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.01 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.01.58 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.11.02 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.31 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.11.57 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.15 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.03.17 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.05.19 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.04.34 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.13.35 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.13.58 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_6.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.00.17 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.33 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.58 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.14.43 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_5.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.00.23 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.04.39 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.00.35 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.07.32 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.18.02 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.15.08 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.20.39 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.02.53 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.37 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.14.53 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.04 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.01.03 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.02.05 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.07.05 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.02.45 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_16.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.05.46 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.43 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.00.43 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.29 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.55 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.45 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.05.33 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.14.03 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.01.36 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.19.36 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.32 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.38 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.01 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.05 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.41 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.11.45 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.28 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.15.27 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.02.41 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.13.29 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.14.18 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.32 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.02.20 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.03.21 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.11.10 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_13.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.11 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.01.23 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.54 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_1.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.02.33 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.20.21 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.19.43 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.36 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.52 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.13.51 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.15.01 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.01.32 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.16.08 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_9.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.05 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_18.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.18.23 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_17.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.05.27 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.53 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_11.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.03.27 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.04.01 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.13.19 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.03.01 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.13.44 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.18.27 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.15.21 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.07.10 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.10 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.16.22 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.07.46 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.19 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.02.11 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.38 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.18.40 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_15.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.07.17 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_2.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.43 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.51 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_8.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.54 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.04.12 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_7.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.07.39 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.03.44 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.49 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.00.02 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.59 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_14.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.43 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.04.46 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.48 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_12.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.19 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.18.52 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.16 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.00.54 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.10 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.03.34 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.14.09 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.01.49 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.16.45 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.04.26 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.25 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_3.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.02 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.57 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.03.55 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.00.06 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.16.33 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.16.16 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.15.13 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.10 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.06.28 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.09 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.11.28 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_19.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_4.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.14.32 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.16.54 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.08.17 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.01.10 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.15.39 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.09.14 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.20.15 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.04.51 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.17.37 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.20.06 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.19.17 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.13.24 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.19.08 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.18.07 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.11.17 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.05.13 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.12.04 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/fixed_orange_10.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.27 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.10.21 AM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-12 at 11.59.23 PM.jpg is already a JPEG. Skipping.
# fruits/train/orange/Screen Shot 2018-06-13 at 12.20.25 AM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_15.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.26 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.25 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.02.08 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_0_7.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.00.35 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_8.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.19.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.05.34 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.57 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.02 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.17.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.05.18 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_0_13.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.10 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.07.05 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_1.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.44 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_0.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.08.46 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.34 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.05.06 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.06 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.20.56 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_9.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.44 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.18.26 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.02.43 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.05.27 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 4.59.36 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.14.20 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.08.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.07.18 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.00.12 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.24 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.12.14 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.00.26 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.12.56 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.10.53 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_13.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.10 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.12.20 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.08.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.14 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.02.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.14.01 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.52 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.39 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.14.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.20.32 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.22.20 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.05.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_12.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.03 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.10 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.40 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.01.15 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.10.03 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.17.10 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 4.59.44 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.19.47 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.20.42 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.02.31 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.47 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.35 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.01.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.21 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.33 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.17.22 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.10 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.31 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.33 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_16.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.59 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.59 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.12.47 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.20.08 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.23 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.05.12 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.00.03 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.19 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.00.18 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.12.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_4.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.40 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_2.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.49 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.08.05 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.19.35 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.02.24 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.01.22 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.10.29 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.07.32 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.34 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.25 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.40 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_11.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.59 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.02.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.17.42 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_3.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.07.52 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.47 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.05 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.01.34 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.24 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.28 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.17 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.31 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.18.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.01.08 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.22.15 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_0_4.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 4.59.57 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.02 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_10.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.22 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.00.43 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.45 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.10.11 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.06.28 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.11 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.16 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.00.50 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_0_18.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.28 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.51 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.08 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.31 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_7.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.18.51 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.01 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_19.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_6.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.16 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.42 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_17.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.03.47 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.01.29 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.14.44 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_0_2.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.02.38 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.06 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 4.59.49 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_5.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.40 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.14.56 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.09.17 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.18.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.05 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.19.15 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.20.26 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.17.04 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.56 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_0_1.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.10.43 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.18.12 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_14.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.12.29 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.10.21 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.05.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.15.09 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.18.42 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.40 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/fixed_apple_18.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.21.35 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.17.34 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.07.26 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.20.51 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.11.52 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.45 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.13.18 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.18.16 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.12.34 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.01.01 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.19.28 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.08.52 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.10.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.04.31 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.16.16 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.20.17 PM.jpg is already a JPEG. Skipping.
# fruits/train/apple/Screen Shot 2018-06-08 at 5.14.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.51.36 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.53 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.01.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.44 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.48.39 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.06 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.25 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.48.26 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.42 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_3.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.27 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.21 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.13 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.55 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.21 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.19 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.42 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.03 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.23 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.48.14 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.33 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.31 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.53 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.46.24 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_11.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.18 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.51 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.46.30 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.46.43 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.27 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.38 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.49 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.16 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_18.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.02.19 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.07.46 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_12.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.38 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.51 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.01.46 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.48.21 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.05.35 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.39 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.58.16 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.54.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.26 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.02 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.34 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.05.20 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.49.00 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.00 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.49.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.51.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.01.52 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.39 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.04.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_9.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_19.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.49.15 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.30 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.36 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.08 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.04 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_8.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.54.35 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.54.50 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.51.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.05.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.58.49 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.48.04 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_16.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_10.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.24 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.05.29 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.51.44 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_2.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_4.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.02 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.01.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.46.19 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.42 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.12 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.02.09 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_6.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.12 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.46 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.54.18 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.08.01 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.45 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.38 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.57 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.58.36 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.46 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.56 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.01.37 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.07.21 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.50.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.49.45 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_5.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.46.55 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.07.29 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.07.52 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_1.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.46 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.05.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.59 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.12 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_15.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.58 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.04.59 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.46.40 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.02 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.52.50 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.17 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_13.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.33 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.49.32 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.58.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.22 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.22 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.48.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.02.24 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.00 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.30 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.54.02 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.05.13 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.00.12 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.05.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.49.54 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.04.49 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_0.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.54.43 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.58.56 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.51.29 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.48.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.32 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.28 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.02.01 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.01.27 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.07.13 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.51.00 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.33 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.35 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.46 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.47.59 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.46.48 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.16 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.31 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.01.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.57.17 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.06.44 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.53.03 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_0_2.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.54.56 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_14.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.51.24 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/fixed_banana_17.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.41 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.56.28 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.55.19 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.59.07 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 10.02.36 PM.jpg is already a JPEG. Skipping.
# fruits/train/banana/Screen Shot 2018-06-12 at 9.49.23 PM.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (24).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/rambutan-for-diabetics.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/360_F_615563412_9anHCKcgEeHRhHhoHqG7AK1HKJnsJNkw.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (40).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (33).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (50).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/rambutan_tree_photos_x4.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (49).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (35).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/1600px_COLOURBOX6061982.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/fixed_18.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/360_F_555588787_My4KtY6uKf4BuZK2w9ba0F3sjm7NNf8C.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (30).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/7426984082_ba9963dc36_b.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/Rambutan-367x550 (1).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/Image2-10.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/NAIC5597-scaled.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/4138001118_f06e8363f1_b.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/rambutan-tree-1000x1000-500x500.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/IMG_2642.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/R (1).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (46).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/1.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/rambutan-tree.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/NAIC5604-1200x800.jpg is already a JPEG. Skipping.
# fruits/train/rambutan/Image2-10 (1).jpg is already a JPEG. Skipping.
# fruits/train/rambutan/OIP (37).jpg is already a JPEG. Skipping.
# ...
# fruits/test/orange/Screen Shot 2018-06-12 at 11.50.14 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.40 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.51.47 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.26 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.12 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.55 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.55.00 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.55.05 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.53.53 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.51.08 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.50.33 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.51 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.53.17 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.21 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.55.28 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.54.44 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.55.37 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.53.12 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.50.47 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.54.35 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.50.19 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.54.27 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.54.20 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.50.28 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.55.23 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.03 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.53.43 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.53.22 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.54.10 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.16 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.51.13 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.46 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.55.42 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.52.32 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.50.54 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.54.55 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.53.33 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.50.41 PM.jpg is already a JPEG. Skipping.
# fruits/test/orange/Screen Shot 2018-06-12 at 11.51.02 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.27.19 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.13 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.47 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.33.05 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.32.50 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.32 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.34.07 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.27.06 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.33.55 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.48 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.36 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.34.01 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.04 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.38 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.33.11 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.05 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.32.38 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.29 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.29.07 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.33.33 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.24 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.15 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.32.43 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.34.21 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.33.47 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.42 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.33.18 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.52 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.32.33 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.27.13 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.58 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.29.13 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.33.27 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.41 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.27.27 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.34.14 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.29.24 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.27.49 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.25.54 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.27.34 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.27.54 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.29.18 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.10 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.29.31 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.19 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.28.59 PM.jpg is already a JPEG. Skipping.
# fruits/test/apple/Screen Shot 2018-06-08 at 5.26.24 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.40.43 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.45.02 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.46.02 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.44.49 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.46.07 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.32 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.59 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.41 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.41.18 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.40.49 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.41.26 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.18 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.45.46 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.35 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.29 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.44.55 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.53 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.46.12 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.49 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.41.43 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.45.28 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.45.15 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.44.40 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.27 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.41.57 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.41.03 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.45.34 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.44 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.44.19 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.44.30 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.45.40 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.40.56 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.11 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.40.38 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.09 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.45.22 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.41.30 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.42.03 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.03 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.48 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.44.06 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.43.39 PM.jpg is already a JPEG. Skipping.
# fruits/test/banana/Screen Shot 2018-06-12 at 9.41.38 PM.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_1600px_COLOURBOX6061982.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/R (5).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutans-hairy-fruits-fresh-harvest-tropical.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_rambutan_tree_photos_x4.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_rambutan-for-diabetics.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (66).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_OIP (49).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_OIP (50).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (63).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (57).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan-fruits-david-gn (1).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (74).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_OIP (33).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_OIP (40).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/GettyImages-688967771-58bd90bf5f9b58af5cd5a411 (3).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (56).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (54).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rare-fruits-tout (2).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan (2).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (58).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rare-fruits-tout (1).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan (8).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (51).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rau-qua.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/GettyImages-688967771-58bd90bf5f9b58af5cd5a411 (4).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan (1).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/GettyImages-688967771-58bd90bf5f9b58af5cd5a411 (2).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (53).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (76).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/DSC09853.JPG is already a JPEG. Skipping.
# fruits/test/rambutan/image (1).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (61).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (68).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_360_F_615563412_9anHCKcgEeHRhHhoHqG7AK1HKJnsJNkw.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (64).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (73).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (62).jpg is already a JPEG. Skipping.
# Error converting fruits/test/rambutan/rambutan-fruit (1).avif: cannot identify image file 'fruits/test/rambutan/rambutan-fruit (1).avif'
# fruits/test/rambutan/R (6).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/Rambutan-1024x683.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/1000_F_98780309_GgifQAFU5ZNwxiL6A0MCGSEXo7SKxMz3.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (75).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (67).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (71).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/Image2-10 (2).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (59).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/what-is-rambutan.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (55).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (60).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (65).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (52).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_OIP (35).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (69).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/coverimage-1543497143 (1).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan (10).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan-fruits-david-gn.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan.jpg is already a JPEG. Skipping.
# fruits/test/rambutan/copied_OIP (24).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/rambutan (9).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/GettyImages-688967771-58bd90bf5f9b58af5cd5a411 (1).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (72).jpg is already a JPEG. Skipping.
# fruits/test/rambutan/OIP (70).jpg is already a JPEG. Skipping.

# %%
class_names = ["apple", "banana", "orange", "rambutan"]
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Rescaling(1./255),
     tf.keras.layers.Conv2D(32, 3, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 3, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 3, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(128, activation="relu"),
     tf.keras.layers.Dense(4)
    ]
)

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 20
)
# Out:
# Epoch 1/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9671 - loss: 0.1174 - val_accuracy: 0.9182 - val_loss: 0.1808
# Epoch 2/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9521 - loss: 0.1232 - val_accuracy: 0.9818 - val_loss: 0.0918
# Epoch 3/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9513 - loss: 0.1437 - val_accuracy: 0.9727 - val_loss: 0.1172
# Epoch 4/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9552 - loss: 0.1195 - val_accuracy: 0.9727 - val_loss: 0.0990
# Epoch 5/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9716 - loss: 0.0814 - val_accuracy: 0.9545 - val_loss: 0.0913
# Epoch 6/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9882 - loss: 0.0483 - val_accuracy: 0.9727 - val_loss: 0.0870
# Epoch 7/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9896 - loss: 0.0408 - val_accuracy: 0.9727 - val_loss: 0.0931
# Epoch 8/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9951 - loss: 0.0267 - val_accuracy: 0.9727 - val_loss: 0.1195
# Epoch 9/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9776 - loss: 0.0629 - val_accuracy: 0.9727 - val_loss: 0.0916
# Epoch 10/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9777 - loss: 0.0595 - val_accuracy: 0.9818 - val_loss: 0.0846
# Epoch 11/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9987 - loss: 0.0311 - val_accuracy: 0.9818 - val_loss: 0.0733
# Epoch 12/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9917 - loss: 0.0319 - val_accuracy: 0.9636 - val_loss: 0.0914
# Epoch 13/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.9545 - val_loss: 0.1286
# Epoch 14/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9829 - loss: 0.0475 - val_accuracy: 0.9818 - val_loss: 0.0894
# Epoch 15/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9888 - loss: 0.0318 - val_accuracy: 0.9818 - val_loss: 0.0984
# Epoch 16/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9889 - loss: 0.0598 - val_accuracy: 0.9818 - val_loss: 0.1128
# Epoch 17/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9570 - loss: 0.1108 - val_accuracy: 0.9545 - val_loss: 0.1160
# Epoch 18/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9861 - loss: 0.0447 - val_accuracy: 0.9545 - val_loss: 0.1458
# Epoch 19/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9911 - loss: 0.0323 - val_accuracy: 0.9636 - val_loss: 0.1170
# Epoch 20/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9998 - loss: 0.0190 - val_accuracy: 0.9727 - val_loss: 0.1068

# %% [markdown]
# Test the model

# %%
for images, labels in test_ds:
    predictions = model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)

    for i in range(len(labels)):
        true = labels[i].numpy()
        pred = predicted_labels[i]
        if true != pred:
            class_name = class_names[true]
            img_array = tf.keras.preprocessing.image.array_to_img(images[i])
            save_path = f"fruits/train/{class_name}/fixed_{class_name}_{i}.jpg"
            img_array.save(save_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
model.evaluate(test_ds)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0071
# [0.006715845782309771, 1.0]

# %%
import numpy

plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %% [markdown]
# Save the model

# %%
model.save('fruitmodel.keras')
